# %% [markdown]
# # Week1_Lab1
# * Review of Probability Theory
# * Random variables.
# * Density.
# * Distributions
# * Expected value

# %% [markdown]
# # Importing required libraries

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
from collections import Counter
import math

import scipy.stats as stats

from scipy.stats import uniform # uniform distribution
from scipy.stats import binom # binomial distribution
from scipy.stats import bernoulli # bernoulli distribution
from scipy.stats import poisson # poisson distribution
from scipy.stats import expon # exponential distribution
from scipy.stats import norm # normal distribution

sns.set()
# %matplotlib inline

np.set_printoptions(precision=2, suppress=True) # threshold=sys.maxsize)

import sys
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-whitegrid')
# matplotlib.style.use('ggplot')
# plt.rcParams["figure.figsize"] = (8, 8)

# %% [markdown]
# **NumPy** is the fundamental package for scientific computing in Python. It is a Python library that provides a multidimensional array object, various derived objects (such as masked arrays and matrices), and an assortment of routines for fast operations on arrays, including mathematical, logical, shape manipulation, sorting, selecting, I/O, discrete Fourier transforms, basic linear algebra, basic statistical operations, random simulation and much more.
#
# **Pandas** is a Python library for PAN-el DA-ta manipulation and analysis, e.g. multidimensional time series and cross-sectional data sets commonly found in statistics, experimental science results, econometrics, or finance. pandas is implemented primarily using NumPy and Cython; it is intended to be able to integrate very easily with NumPy-based scientific libraries, such as statsmodels.
#
# **statsmodels** is a Python module that provides classes and functions for the estimation of many different statistical models, as well as for conducting statistical tests, and statistical data exploration. An extensive list of result statistics are available for each estimator. The results are tested against existing statistical packages to ensure that they are correct.
#
# **SciPy** is a collection of mathematical algorithms and convenience functions built on the NumPy extension of Python. It adds significant power to the interactive Python session by providing the user with high-level commands and classes for manipulating and visualizing data. With SciPy, an interactive Python session becomes a data-processing and system-prototyping environment rivaling systems, such as MATLAB, IDL, Octave, R-Lab, and SciLab.
# The additional benefit of basing SciPy on Python is that this also makes a powerful programming language available for use in developing sophisticated programs and specialized applications. Scientific applications using SciPy benefit from the development of additional modules in numerous niches of the software landscape by developers across the world. Everything from parallel programming to web and data-base subroutines and classes have been made available to the Python programmer. All of this power is available in addition to the mathematical libraries in SciPy.
#
# **Matplotlib** is a comprehensive library for creating static, animated, and interactive visualizations in Python.
#
# **Seaborn** is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# ### Coin toss:

# %% [markdown]
# $
#   \text{Sample space} =
#     \begin{cases}
#       Head\\
#       Tail\\
#     \end{cases}
# $
#
#
# $
#   \text{Random variable (outcome)} =
#     \begin{cases}
#       1, & \text{if outcome is Head}\\
#       0, & \text{if outcome is Tail}\\
#     \end{cases}
# $
#
# $
#   \text{Probability mass function (random variable)} =
#     \begin{cases}
#       \frac{1}{2}, & \text{if random variable is equal to 1}\\
#       \frac{1}{2}, & \text{if random variable is equal to 0}\\
#     \end{cases}
# $

# %%
number_of_trials = 1000
head_tail = [random.randint(0,1) for i in range(number_of_trials)]
print('Number of Heads: {}, probability of getting Head: {}'.format(head_tail.count(1), head_tail.count(1)/number_of_trials))
print('Number of Tails: {}, probability of getting Tail: {}'.format(head_tail.count(0), head_tail.count(0)/number_of_trials))
# Out:
# Number of Heads: 507, probability of getting Head: 0.507
# Number of Tails: 493, probability of getting Tail: 0.493

# %%
plt.bar(dict(Counter(head_tail)).keys(), dict(Counter(head_tail)).values())
plt.xlabel('Outcomes',fontsize=14)
plt.ylabel('Probability',fontsize=14)
plt.xticks([0,1])
plt.show()

# %% [markdown]
# [Probability distribution](https://en.wikipedia.org/wiki/Probability_distribution) is the mathematical function that gives the probabilities of occurrence of different possible outcomes for an experiment.

# %% [markdown]
# What is the probability distribution of getting heads in 5 coin tosses?

# %% [markdown]
# X - number of heads (random variable)

# %%
def nCr(n,r):
    f = math.factorial
    return f(n) / f(r) / f(n-r)

number_of_tosses = 10
probability_of_head = 0.5
number_of_heads = []
probabilities_for_heads = []
for i in range(number_of_tosses+1):
    prob_of_head = probability_of_head**i                             #for this number of heads
    prob_of_tail = (1-probability_of_head)**(number_of_tosses-i)      #for this number of heads
    prob_of_outcome = nCr(number_of_tosses,i)*prob_of_head*prob_of_tail
    print('Probability of occurence {} heads in {} tosses is {}'.format(i, number_of_tosses, prob_of_outcome))
    number_of_heads.append(i)
    probabilities_for_heads.append(prob_of_outcome)
# Out:
# Probability of occurence 0 heads in 10 tosses is 0.0009765625
# Probability of occurence 1 heads in 10 tosses is 0.009765625
# Probability of occurence 2 heads in 10 tosses is 0.0439453125
# Probability of occurence 3 heads in 10 tosses is 0.1171875
# Probability of occurence 4 heads in 10 tosses is 0.205078125
# Probability of occurence 5 heads in 10 tosses is 0.24609375
# Probability of occurence 6 heads in 10 tosses is 0.205078125
# Probability of occurence 7 heads in 10 tosses is 0.1171875
# Probability of occurence 8 heads in 10 tosses is 0.0439453125
# Probability of occurence 9 heads in 10 tosses is 0.009765625
# Probability of occurence 10 heads in 10 tosses is 0.0009765625

# %%
plt.bar(number_of_heads, probabilities_for_heads)
plt.xlabel('Number of heads',fontsize=14)
plt.ylabel('Probability',fontsize=14)
plt.xticks(range(number_of_tosses+1))
plt.show()

# %%
expected_value_for_1_toss = 1*probability_of_head + 0*(1-probability_of_head)
print('Expected value of revenue in one toss is {}'.format(expected_value_for_1_toss))
# Out:
# Expected value of revenue in one toss is 0.5

# %%
n = 6
expected_value_for_n_toss = 0
for i in range(n+1):
    expected_value_for_n_toss += 0.5**n * nCr(n,i) * i
print('Expected value of revenue in {} toss is {}'.format(n, expected_value_for_n_toss))
# Out:
# Expected value of revenue in 6 toss is 3.0

# %% [markdown]
# Find expected value and variance of ξ:
#
# ![Снимок.PNG](data:image/png;base64,...)

# %%
expected_value = -1 * 1/4 + 0 * 1/4 + 2 * 1/2
expected_value_of_square = 1 * 1/4 + 0 * 1/4 + 4 * 1/2
variance = expected_value_of_square - expected_value**2
print('Expected value: {}. Variance: {}'.format(expected_value, variance))
# Out:
# Expected value: 0.75. Variance: 1.6875

# %% [markdown]
# ### Probability mass function, probability density function, cumulative distribution function.

# %% [markdown]
# If we throw a dice, then in any case we will get one of 6 numbers:
#
# $
#   \text{Probability mass function (dice)} =
#     \begin{cases}
#       \frac{1}{6}, & \text{if the dice rolled 1}\\
#       \frac{1}{6}, & \text{if the dice rolled 2}\\
#       \frac{1}{6}, & \text{if the dice rolled 3}\\
#       \frac{1}{6}, & \text{if the dice rolled 4}\\
#       \frac{1}{6}, & \text{if the dice rolled 5}\\
#       \frac{1}{6}, & \text{if the dice rolled 6}\\
#     \end{cases}
# $

# %%
plt.bar(number_of_heads, probabilities_for_heads) #just an example of discrete distribution
plt.xticks(range(number_of_tosses+1))
plt.show()

# %% [markdown]
# But given the height of people, the probability that a randomly selected person has a height of 170 cm is almost zero. The height can be equal to 170,1 cm or 170,31 cm. It is a continuous variable! We can look at the probability that a randomly selected person has a height from 170,0 cm to 170,9 cm.

# %%
mu = 0 #just an example of continuous distribution
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %% [markdown]
# The line is a graph of a probability density function. The area under the curve represents the value of cumulative distribution function (remember the integral that you have to take in order to find the probability!!!)

# %% [markdown]
# ### Distributions

# %%
df = pd.read_csv('https://raw.githubusercontent.com/a1ip/Abbakumov/master/Lesson_02/swiss_bank_notes.csv', index_col=0)
df.head()
# Out:
#     Status  Length   Left  Right  Bottom   Top  Diagonal
# 1  genuine   214.8  131.0  131.1     9.0   9.7     141.0
# 2  genuine   214.6  129.7  129.7     8.1   9.5     141.7
# 3  genuine   214.8  129.7  129.7     8.7   9.6     142.2
# 4  genuine   214.8  129.7  129.6     7.5  10.4     142.0
# 5  genuine   215.0  129.6  129.7    10.4   7.7     141.8

# %% [markdown]
# <strong/>Status</strong> - the status of the banknote: genuine or counterfeit
#
# <strong/>Length</strong> - Length of bill (mm)
#
# <strong/>Left</strong> - Width of left edge (mm)
#
# <strong/>Right</strong> - Width of right edge (mm)
#
# <strong/>Bottom</strong> - Bottom margin width (mm)
#
# <strong/>Top</strong> - Top margin width (mm)
#
# <strong/>Diagonal</strong> - Length of diagonal (mm)

# %%
df.describe()
# Out:
#            Length        Left       Right      Bottom         Top    Diagonal
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   214.896000  130.121500  129.956500    9.417500   10.650500  140.483500
# std      0.376554    0.361026    0.404072    1.444603    0.802947    1.152266
# min    213.800000  129.000000  129.000000    7.200000    7.700000  137.800000
# 25%    214.600000  129.900000  129.700000    8.200000   10.100000  139.500000
# 50%    214.900000  130.200000  130.000000    9.100000   10.600000  140.450000
# 75%    215.100000  130.400000  130.225000   10.600000   11.200000  141.500000
# max    216.300000  131.000000  131.100000   12.700000   12.300000  142.400000

# %% [markdown]
# Can we detect a conterfeit banknote without help of machine learning?

# %%
df['Length'].hist()
# y-axis = number of banknotes
# x-axis = length
# Out:
# <Axes: >

# %%
df.groupby('Status')['Length'].plot.hist()
plt.legend()

# %% [markdown]
# Taking into consideration only length of banknotes, we cannot detect counterfeit bills!

# %%
df['Diagonal'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Two peaks are ... ???

# %% [markdown]
# Mode is the value that appears most often in a set.

# %%
df.groupby('Status')['Diagonal'].plot.hist()
plt.legend()
plt.show()

# %% [markdown]
# Can you see the difference between real and fake?

# %%
df['Length'].plot(kind='box')
plt.title('Distribution of a length')
plt.show()

# %%
df['Length'].describe()
# Out:
# count    200.000000
# mean     214.896000
# std        0.376554
# min      213.800000
# 25%      214.600000
# 50%      214.900000
# 75%      215.100000
# max      216.300000
# Name: Length, dtype: float64

# %% [markdown]
# Median - the middle value of the given list of data, when arranged in an order.

# %% [markdown]
# Ranking is needed to find percentiles!

# %%
lengths = sorted(list(df['Length']))
length_25 = lengths[len(lengths)//4]
length_75 = lengths[len(lengths)//4*3]
length_25, length_75
# Out:
# (214.6, 215.1)

# %% [markdown]
# QUESTION!
#
# When is it better to use the mode or median as the central trend instead of the mean?

# %%
df['Length'].max() - df['Length'].min() #range
# Out:
# 2.5

# %%
df['Length'].std() #standard deviation - the average deviation of all the points from the mean
# Out:
# 0.3765540662695334

# %% [markdown]
# ## Time to practice

# %% [markdown]
# Look at the Titanic dataset.

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#start of your code
#use matplotlib.pyplot
...
#end of your code

# %%
#start of your code
#use pandas library
...
#end of your code
# Out:
#    Pclass  Survived
# 2       3       491
# 0       1       216
# 1       2       184

# %%
#start of your code
#use pandas library
...
#end of your code
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
#start of your code
#use pandas cross tables
...
#end of your code
# Out:
# <style type="text/css">
# #T_3bd50_row0_col0, #T_3bd50_row0_col1, #T_3bd50_row0_col3, #T_3bd50_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_3bd50_row0_col2, #T_3bd50_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_3bd50_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_3bd50_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_3bd50_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_3bd50_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_3bd50_row2_col1, #T_3bd50_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_3bd50_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_3bd50_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_3bd50_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_3bd50_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_3bd50_row4_col0, #T_3bd50_row4_col1, #T_3bd50_row4_col2, #T_3bd50_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3bd50" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_3bd50_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_3bd50_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_3bd50_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_3bd50_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bd50_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_3bd50_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_3bd50_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_3bd50_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_3bd50_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_3bd50_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_3bd50_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_3bd50_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_3bd50_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_3bd50_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_3bd50_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_3bd50_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_3bd50_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_3bd50_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_3bd50_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_3bd50_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_3bd50_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_3bd50_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_3bd50_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_3bd50_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_3bd50_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_3bd50_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_3bd50_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_3bd50_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_3bd50_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_3bd50_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_3bd50_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_3bd50_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
#start of your code
#use seaborn library
...
#end of your code

# %%
print('Oldest person Survived was of:', #your code)
print('Youngest person Survived was of:', #your code)
print('Average person Survived was of:', #your code)
# Out:
# Oldest person Survived was of: 80.0
# Youngest person Survived was of: 0.42
# Average person Survived was of: 28.343689655172415
