# %% [markdown]
# # Importing required libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
from collections import Counter
import math

import scipy.stats as stats

from scipy.stats import uniform # uniform distribution
from scipy.stats import binom # binomial distribution
from scipy.stats import bernoulli # bernoulli distribution
from scipy.stats import poisson # poisson distribution
from scipy.stats import expon # exponential distribution
from scipy.stats import norm # normal distribution

sns.set()
# %matplotlib inline

np.set_printoptions(precision=2, suppress=True) # threshold=sys.maxsize)

import sys
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-whitegrid')
# plt.rcParams["figure.figsize"] = (8, 8)

# %% [markdown]
# # The Uniform distribution

# %% [markdown]
# **The Uniform distribution from a to b**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#taking random variables from Uniform distribution
data_uniform = uniform.rvs(size = 100000, loc = 5, scale=10)

#Plotting the results
ax = sns.distplot(data_uniform, bins = 30, color = 'k')
ax.set(xlabel = 'interval')
plt.show()

# %% [markdown]
# # The Binomial Distribution

# %% [markdown]
# We observe a Bernoulli trial (S,F) n times.
# Let X denote the number of successes in the n trials.
# Then X has a **binomial distribution**, i. e.
#
# ![image.png](data:image/png;base64,...)
#
# where
# 1. $p$ = the probability of success (S), and
# 2. $q = 1 – p$ = the probability of failure (F)

# %%
#Applying the binom class
pb = binom(n = 20, p = 0.6)

x = np.arange(1,21)
pmf = pb.pmf(x)

#Visualizing the distribution
plt.vlines(x ,0, pb.pmf(x), colors='k', linestyles='-', lw=5)
plt.ylabel('Probability')
plt.xlabel('Intervals')
plt.show()

# %% [markdown]
# # The Bernoulli Distribution

# %% [markdown]
# The probability distribution with probability function
#
# ![image.png](data:image/png;base64,...)
#
# is called the **Bernoulli distribution**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Applying the bernoulli class
data_bernoulli = bernoulli.rvs(size = 1000 , p = 0.8)

#Visualizing the results
sns.displot(data_bernoulli, discrete=True, shrink=.8 , color = 'k')
plt.show()

# %% [markdown]
# # The Puasson Distribution

# %% [markdown]
# * Suppose events are occurring randomly and uniformly in time.
# * Let $X$ be the number of events occurring in a fixed period time. Then $X$ will have a **Poisson distribution** with parameter $\lambda$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Applying the poisson class methods
x = np.arange(0,10)
pmf = poisson.pmf(x,3)

#Visualizing the results
plt.vlines(x ,0, pmf, colors='k', linestyles='-', lw=6)
plt.ylabel('Probability')
plt.xlabel('intervals')
plt.show()

# %% [markdown]
# # The Exponential distribution

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Applying the expon class methods
x = np.linspace(0.001,10, 100)
pdf = expon.pdf(x)

#Visualizing the results
plt.plot(x, pdf , 'r-', lw=2, alpha=0.6, label='expon pdf' , color = 'k')
plt.xlabel('intervals')
plt.ylabel('Probability Density')
plt.show()

# %% [markdown]
# # The Normal Distribution

# %% [markdown]
# The Normal distribution (mean $mu$, standard deviation $\sigma$)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Creating the distribution
data_normal = np.arange(1,10,0.01)
pdf = norm.pdf(data_normal , loc = 5.3 , scale = 1 )
 
#Visualizing the distribution
sns.lineplot(data_normal, pdf , color = 'black')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')
